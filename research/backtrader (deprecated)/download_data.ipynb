# %%
from alpaca.data.historical import StockHistoricalDataClient
from alpaca.data.requests import StockBarsRequest
from alpaca.data.timeframe import TimeFrame
from datetime import datetime
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("APCA_API_KEY_ID")
secret_key = os.getenv("APCA_API_SECRET_KEY")

# %%
# No keys required for stock data
client = StockHistoricalDataClient(api_key, secret_key)

# Set up the request parameters
request_params = StockBarsRequest(
    symbol_or_symbols=["NVDA"],
    timeframe=TimeFrame.Day,
    start=datetime(2000, 1, 1),
)

# Get the data
bars = client.get_stock_bars(request_params)

# Convert to pandas DataFrame
df = bars.df
print(df)
# Out:
#                                      open     high      low   close  \
# symbol timestamp
# NVDA   2016-01-04 05:00:00+00:00   32.290   32.580   32.040   32.37
#        2016-01-05 05:00:00+00:00   32.980   33.440   32.500   32.89
#        2016-01-06 05:00:00+00:00   32.350   32.500   31.160   31.53
#        2016-01-07 05:00:00+00:00   30.740   30.953   29.880   30.28
#        2016-01-08 05:00:00+00:00   30.670   30.700   29.565   29.63
# ...                                   ...      ...      ...     ...
#        2025-11-21 05:00:00+00:00  181.235  184.560  172.930  178.88
#        2025-11-24 05:00:00+00:00  179.490  183.500  176.480  182.55
#        2025-11-25 05:00:00+00:00  174.910  178.160  169.550  177.82
#        2025-11-26 05:00:00+00:00  181.630  182.910  178.240  180.26
#        2025-11-28 05:00:00+00:00  179.010  179.290  176.500  177.00
#
#                                        volume  trade_count        vwap
# symbol timestamp
# NVDA   2016-01-04 05:00:00+00:00    9777779.0      56932.0   32.290167
#        2016-01-05 05:00:00+00:00   13406139.0      64465.0   33.024588
#        2016-01-06 05:00:00+00:00   11606505.0      70692.0   31.818124
#        2016-01-07 05:00:00+00:00   16989171.0      97956.0   30.346467
#        2016-01-08 05:00:00+00:00   10461559.0      60419.0   30.069429
# ...                                       ...          ...         ...
#        2025-11-21 05:00:00+00:00  346926153.0    5306231.0  179.297270
#        2025-11-24 05:00:00+00:00  256618335.0    3403703.0  181.118138
#        2025-11-25 05:00:00+00:00  320600271.0    4521138.0  174.112096
#        2025-11-26 05:00:00+00:00  183852010.0    2614452.0  180.544334
#        2025-11-28 05:00:00+00:00  126610082.0    1940578.0  177.493809
#
# [2492 rows x 7 columns]

# %%
df.to_csv("data.csv")
